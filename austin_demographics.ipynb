# %%
# Import the nescessary modules
import matplotlib.pyplot as plt
from scipy import stats
# %matplotlib inline
import pandas as pd
import numpy as np
import requests
import json

# %%
valuations = pd.read_csv("./Resources/valuations_by_county.csv")
valuations.head()
# Out:
#          County Name State                             Metro      1/31/21  \
# 0      Travis County    TX  Austin-Round Rock-Georgetown, TX  436552.8788
# 1  Williamson County    TX  Austin-Round Rock-Georgetown, TX  361585.5243
#
#        2/28/21      3/31/21      4/30/21      5/31/21      6/30/21  \
# 0  446421.4051  457875.4995  471973.8428  488228.7030  504310.9044
# 1  368822.6790  377712.2904  388716.1068  402092.3518  415289.9965
#
#        7/31/21  ...      3/31/22      4/30/22      5/31/22      6/30/22  \
# 0  515930.0798  ...  569823.8473  585724.8250  599291.9096  607264.6187
# 1  425375.9195  ...  476564.6104  489009.3206  499409.4834  505448.3923
#
#        7/31/22      8/31/22      9/30/22     10/31/22     11/30/22  \
# 0  607827.7831  602717.9176  594274.9308  586305.8113  578777.6838
# 1  505208.6748  500339.0285  492831.8333  485452.8285  478004.7077
#
#       12/31/22
# 0  570721.4868
# 1  470347.3179
#
# [2 rows x 27 columns]

# %%
valuations_2021 = pd.DataFrame(valuations, columns=["1/31/2021", "2/28/2021", "3/31/2021", "4/30/2021", "5/31/2021", "6/30/2021", "7/31/2021", "8/31/2021", "9/30/2021", "10/31/2021", "11/30/2021", "12/31/2021"])
valuations_2021
# Out:
#    1/31/2021  2/28/2021  3/31/2021  4/30/2021  5/31/2021  6/30/2021  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
#
#    7/31/2021  8/31/2021  9/30/2021  10/31/2021  11/30/2021  12/31/2021
# 0        NaN        NaN        NaN         NaN         NaN         NaN
# 1        NaN        NaN        NaN         NaN         NaN         NaN

# %%
williamson = pd.read_csv("./Resources/williamson.csv", header=1)
williamson.head()
# Out:
#                        Unnamed: 0 Total population White alone  \
# 0                           Label         Estimate    Estimate
# 1  TOTAL NUMBER OF RACES REPORTED              NaN         NaN
# 2                Total population        1,305,154     717,362
# 3                        One race           80.90%     100.00%
# 4                       Two races           18.40%         (X)
#
#   White alone or in combination with one or more other races  \
# 0                                           Estimate
# 1                                                NaN
# 2                                            954,519
# 3                                             75.20%
# 4                                             23.90%
#
#   Black or African American alone  \
# 0                        Estimate
# 1                             NaN
# 2                         102,957
# 3                         100.00%
# 4                             (X)
#
# ...

# %%
williamson.dropna(inplace=True)
williamson.head()
# Out:
#          Unnamed: 0 Total population White alone  \
# 0             Label         Estimate    Estimate
# 2  Total population        1,305,154     717,362
# 3          One race           80.90%     100.00%
# 4         Two races           18.40%         (X)
# 5       Three races            0.60%         (X)
#
#   White alone or in combination with one or more other races  \
# 0                                           Estimate
# 2                                            954,519
# 3                                             75.20%
# 4                                             23.90%
# 5                                              0.90%
#
#   Black or African American alone  \
# 0                        Estimate
# 2                         102,957
# 3                         100.00%
# 4                             (X)
# 5                             (X)
#
#   Black or African American alone or in combination with one or more other races  \
# ...

# %%
travis = pd.read_csv("./Resources/travis.csv", header=1)
travis.head()
# Out:
#                        Unnamed: 0 Total population White alone  \
# 0                           Label         Estimate    Estimate
# 1  TOTAL NUMBER OF RACES REPORTED              NaN         NaN
# 2                Total population        1,305,154     717,362
# 3                        One race           80.90%     100.00%
# 4                       Two races           18.40%         (X)
#
#   White alone or in combination with one or more other races  \
# 0                                           Estimate
# 1                                                NaN
# 2                                            954,519
# 3                                             75.20%
# 4                                             23.90%
#
#   Black or African American alone  \
# 0                        Estimate
# 1                             NaN
# 2                         102,957
# 3                         100.00%
# 4                             (X)
#
# ...

# %%
travis.dropna(inplace=True)
travis.head()
# Out:
#          Unnamed: 0 Total population White alone  \
# 0             Label         Estimate    Estimate
# 2  Total population        1,305,154     717,362
# 3          One race           80.90%     100.00%
# 4         Two races           18.40%         (X)
# 5       Three races            0.60%         (X)
#
#   White alone or in combination with one or more other races  \
# 0                                           Estimate
# 2                                            954,519
# 3                                             75.20%
# 4                                             23.90%
# 5                                              0.90%
#
#   Black or African American alone  \
# 0                        Estimate
# 2                         102,957
# 3                         100.00%
# 4                             (X)
# 5                             (X)
#
#   Black or African American alone or in combination with one or more other races  \
# ...

# %%
#
